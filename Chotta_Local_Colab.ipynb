# %% [markdown]
# # 🎬 The Ultimate Pro AI Video Agent (F5-TTS Voice Cloning 🇹🇭)
#
# สมุดโน้ตนี้ถูกตั้งค่ามาให้โคลนโปรเจ็กต์ล่าสุดจาก GitHub ของคุณ (`Tatsuyato/Chotta`) เพื่อมารันระบบ F5-TTS-TH-V2 โคลนเสียงภาษาไทย ตัดต่อและวิเคราะห์คลิปยาวบน Google Colab (ใช้ GPU ฟรี)

# %%
# 1. ตรวจสอบการเปิดใช้งาน GPU ของ Google Colab
# !nvidia-smi

# %%
# 2. โคลนโปรเจ็กต์จาก GitHub
# !rm -rf Chotta # ลบโฟลเดอร์เก่าทิ้ง (ถ้ามี) เพื่อให้ได้โค้ดล่าสุดเสมอ
# !git clone https://github.com/Tatsuyato/Chotta.git
# %cd Chotta

# %%
# 3. ติดตั้งไลบรารีและดาวน์โหลดโมเดลที่จำเป็นทั้งหมด (F5-TTS, Qwen, Whisper)
# โค้ดนี้จะไปเรียกไฟล์ setup.py เพื่อตั้งค่าตาม requirements.txt ที่เตรียมไว้
# !python setup.py

# %%
# 4. เริ่มต้นการทำงานระบบ Gradio Web UI
# เมื่อรันเสร็จแล้ว ให้คลิกที่ลิงก์ Public URL (xxxx.gradio.live) เพื่อเข้าใช้งานหน้าเว็บ
# !python app.py
